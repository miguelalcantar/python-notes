# %%
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
import tensorflow as tf

# %%
puppy = Image.open('images/Puppy.jpg')

# %%
type(puppy)
# Out:
# PIL.JpegImagePlugin.JpegImageFile

# %%
puppy_arr = np.asarray(puppy)

# %%
type(puppy_arr)
# Out:
# numpy.ndarray

# %%
puppy_arr.shape
# Out:
# (1000, 3000, 3)

# %% [markdown]
# So what's actually an image, from a Computational point of view?
# Is a set of pixels where each one is made by Green, Red and Blue values. That is to say, every pixel represents a single unit of an array of size x,y,3.

# %%
plt.imshow(puppy_arr)

# %%
puppy_arr.shape
# Out:
# (1000, 3000, 3)

# %% [markdown]
# Lets try to visualize the puppy by just red pixels

# %%
puppy_red = puppy_arr.copy()
puppy_red.shape
# Out:
# (1000, 3000, 3)

# %%
# R G B

print(puppy_red[:,:,2].shape)

# puppy_red[:,:,0] = 0
# puppy_red[:,:,1] = 0

# Red Channel values 0-255
plt.imshow(puppy_red[:,:,2],cmap='gray')
# Out:
# (1000, 3000)

# %%
# Green
plt.imshow(puppy_red[:,:,1])

# %%
# Blue
plt.imshow(puppy_red[:,:,2])

# %%
# GREEN CHANNEL
puppy_green = puppy_red
puppy_green[:,:,1] = 0
plt.imshow(puppy_green)

# %%
# BLUE CHANNEL
# puppy_blue = puppy_red
puppy_green[:,:,1] = 0
plt.imshow(puppy_green)

# %%
puppy_green.shape
# Out:
# (1000, 3000, 3)
